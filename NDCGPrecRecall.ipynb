# %%
from collections import defaultdict
import math
# Function to read data from a file and create a dictionary
def read_qrel_relevance(file_path):
    qrel_relevance_dict = {}
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split()
            if len(parts) >= 4:
                qid, doc_id, relevance = parts[0], (parts[2]), int(parts[3])
                if qid not in qrel_relevance_dict:
                    qrel_relevance_dict[qid] = {}
                qrel_relevance_dict[qid][doc_id] = relevance
    return qrel_relevance_dict

# %%
qrels_file_path = './qrel_file/ordered-qrel-msmarco-2019.txt'
scores_file_path = './relevance_file/DYNAMICPRUNINGTFIDFwithRelevance.txt'

# %%
# Step 1: Create data structures
qrels_data = read_qrel_relevance(qrels_file_path)
scores_data = read_qrel_relevance(scores_file_path)

# %%
scores_data
# Out:
# {'1114819': {'785027': 3,
#   '8022279': 1,
#   '1724520': 3,
#   '6941478': 3,
#   '8115706': 0,
#   '8088109': 0,
#   '785028': 2,
#   '8115440': 2,
#   '8088111': 2,
#   '8022277': 0},
#  '573724': {'3365633': 1,
#   '7384332': 1,
#   '3146238': 2,
#   '3365631': 1,
#   '3365638': 1,
#   '3365636': 2,
#   '3365632': 0,
#   '87405': 1,
#   '7609926': 0,
#   '6121093': 0},
#  '1114646': {'8117094': 1,
#   '8117087': 1,
#   '2343617': 0,
#   '6704400': 3,
#   '5417954': 3,
#   '5417953': 1,
#   '6704401': 0,
#   '5417952': 1,
#   '5959593': 1,
#   '6711103': 2},
#  '1103812': {'4401695': 2,
#   '2379408': 0,
#   '5974245': 0,
#   '1785498': 0,
#   '3672744': 0,
#   '2250580': 0,
#   '8224183': 1,
#   '5974240': 0,
#   '3564771': 0,
#   '5201199': 0},
#  '207786': {'2998723': 0,
#   '1085406': 0,
#   '8273763': 1,
#   '4660025': 0,
#   '6309220': 0,
#   '5804666': 0,
#   '8273755': 1,
#   '8185063': 0,
#   '1085404': 0,
#   '8273759': 0},
#  '182539': {'57443': 2,
#   '7371262': 1,
#   '3883077': 1,
#   '8757181': 3,
#   '57448': 1,
#   '7371255': 2,
#   '57447': 1,
#   '57444': 1,
#   '8757178': 1,
#   '2909960': 1},
#  '146187': {'5548651': 0,
#   '6241267': 0,
#   '744165': 1,
#   '3963185': 0,
#   '8434625': 2,
#   '8434623': 2,
#   '8434619': 2,
#   '4921741': 0,
#   '1028971': 0,
#   '1246346': 0},
#  '1106007': {'6126194': 0,
#   '6209484': 0,
#   '7685384': 0,
#   '6126197': 0,
#   '2777113': 0,
#   '7638713': 0,
#   '4120343': 0,
#   '2165342': 0,
#   '8204463': 2,
#   '2384069': 0},
#  '490595': {'3572695': 0,
#   '1929910': 2,
#   '2507917': 0,
#   '5612095': 0,
#   '4737060': 3,
#   '4737065': 1,
#   '1620438': 0,
#   '3572701': 0,
#   '3572698': 0,
#   '4737064': 1},
#  '451602': {'3090666': 0,
#   '4345752': 0,
#   '2922145': 0,
#   '6286981': 2,
#   '3090663': 0,
#   '1277289': 0,
#   '6286974': 2,
#   '6286977': 2,
#   '96224': 0,
#   '4874640': 2},
#  '527433': {'6186391': 1,
#   '4903731': 0,
#   '4958697': 0,
#   '1251475': 0,
#   '269423': 0,
#   '4958696': 0,
#   '1251481': 0,
#   '269428': 0,
#   '269430': 1,
#   '269426': 0},
#  '131843': {'8305152': 3,
#   '985994': 3,
#   '8305156': 3,
#   '8305158': 3,
#   '8305153': 3,
#   '3841396': 3,
#   '985995': 3,
#   '8710813': 3,
#   '4254836': 0,
#   '3400903': 0},
#  '1115776': {'600966': 0,
#   '8106323': 0,
#   '8106318': 1,
#   '8106321': 3,
#   '8106324': 1,
#   '4314171': 0,
#   '4314175': 1,
#   '3081626': 0,
#   '3680291': 0,
#   '1826911': 0},
#  '1121402': {'188213': 2,
#   '5189913': 2,
#   '8052624': 2,
#   '182373': 1,
#   '182368': 2,
#   '188215': 1,
#   '188217': 1,
#   '182364': 1,
#   '188218': 1,
#   '7125983': 2},
#  '156493': {'2411918': 2,
#   '6139386': 3,
#   '8182166': 2,
#   '885944': 2,
#   '8029433': 2,
#   '2317807': 2,
#   '4940228': 2,
#   '6983822': 0,
#   '2616515': 0,
#   '3288596': 2},
#  '87452': {'6018163': 1,
#   '8436571': 0,
#   '6018169': 0,
#   '7965004': 3,
#   '8607555': 0,
#   '6018160': 2,
#   '6018168': 3,
#   '7843984': 1,
#   '6018161': 0,
#   '5286924': 2},
#  '1110199': {'3447960': 0,
#   '554521': 0,
#   '398442': 0,
#   '5600214': 0,
#   '2975909': 0,
#   '3967240': 0,
#   '4558064': 0,
#   '7960023': 0,
#   '7837903': 0,
#   '3722531': 0},
#  '489204': {'1310103': 0,
#   '5583224': 0,
#   '678245': 0,
#   '8737051': 1,
#   '7358643': 0,
#   '216492': 1,
#   '7113153': 1,
#   '1418931': 0,
#   '8737053': 0,
#   '4918001': 0},
#  '47923': {'8348762': 1,
#   '5032362': 1,
#   '1868437': 2,
#   '5417582': 3,
#   '6643066': 3,
#   '1681334': 2,
#   '5417580': 1,
#   '5147527': 1,
#   '5586331': 0,
#   '8418681': 2},
#  '1063750': {'4788295': 0,
#   '3133647': 0,
#   '2997653': 0,
#   '4629006': 0,
#   '6093904': 0,
#   '7607274': 0,
#   '344861': 0,
#   '7778348': 0,
#   '7598863': 0,
#   '6314894': 0},
#  '1113437': {'5188745': 0,
#   '5188746': 0,
#   '2354940': 0,
#   '3518298': 0,
#   '313542': 0,
#   '7385216': 1,
#   '1280572': 0,
#   '742044': 2,
#   '5546289': 0,
#   '6284746': 0},
#  '104861': {'459676': 2,
#   '6658615': 2,
#   '6351571': 2,
#   '459675': 2,
#   '5864693': 2,
#   '5688415': 2,
#   '5150431': 2,
#   '5248340': 2,
#   '8259116': 0,
#   '146178': 0},
#  '1117099': {'1798612': 3,
#   '4131489': 0,
#   '2715359': 0,
#   '1798620': 3,
#   '2715363': 0,
#   '8093931': 3,
#   '4131491': 0,
#   '4441325': 3,
#   '1174584': 0,
#   '3960678': 0},
#  '405717': {'2365660': 0,
#   '7447941': 0,
#   '8433858': 1,
#   '6654655': 0,
#   '2702419': 1,
#   '28368': 0,
#   '5638740': 0,
#   '931517': 0,
#   '7170626': 1,
#   '3033900': 2},
#  '183378': {'4803850': 3,
#   '4493915': 3,
#   '4803856': 1,
#   '3093215': 3,
#   '327908': 3,
#   '4803851': 0,
#   '4493916': 3,
#   '2493332': 1,
#   '2639939': 0,
#   '1289495': 3},
#  '359349': {'68647': 3,
#   '576629': 3,
#   '576628': 2,
#   '2826510': 2,
#   '68653': 2,
#   '3223833': 2,
#   '68648': 3,
#   '943229': 3,
#   '68649': 3,
#   '457673': 2},
#  '264014': {'96854': 1,
#   '1610712': 0,
#   '5635519': 2,
#   '3666584': 1,
#   '6641238': 3,
#   '4239616': 0,
#   '5635521': 2,
#   '6337909': 0,
#   '5611210': 2,
#   '2223171': 2},
#  '130510': {'1494936': 2,
#   '7501563': 1,
#   '7125239': 1,
#   '996732': 1,
#   '1494935': 2,
#   '799647': 3,
#   '1110766': 1,
#   '1494932': 1,
#   '1494930': 1,
#   '996740': 1},
#  '87181': {'5197135': 1,
#   '2986227': 2,
#   '7666831': 1,
#   '6484578': 1,
#   '1902826': 1,
#   '47212': 1,
#   '47207': 1,
#   '4689525': 2,
#   '8151921': 1,
#   '6521366': 2},
#  '1133167': {'5674622': 2,
#   '6467522': 1,
#   '7093509': 2,
#   '8160241': 2,
#   '8255705': 2,
#   '3421900': 2,
#   '3953805': 2,
#   '8160230': 1,
#   '1883281': 2,
#   '190809': 2},
#  '443396': {'456708': 0,
#   '483935': 0,
#   '4774806': 0,
#   '5468743': 0,
#   '2654918': 0,
#   '1465664': 0,
#   '2082395': 0,
#   '8079046': 0,
#   '2654922': 0,
#   '2434039': 0},
#  '1129237': {'2697752': 2,
#   '3905806': 0,
#   '128984': 3,
#   '8682824': 3,
#   '6080460': 3,
#   '4233383': 1,
#   '7688471': 0,
#   '4233385': 0,
#   '1779228': 0,
#   '1721142': 0},
#  '1124210': {'2258595': 2,
#   '2258591': 2,
#   '2258596': 2,
#   '2258598': 2,
#   '2258592': 3,
#   '6541866': 2,
#   '2258594': 2,
#   '8026740': 2,
#   '2258597': 2,
#   '1689639': 2},
#  '915593': {'1396701': 0,
#   '4566815': 0,
#   '4566816': 0,
#   '1396707': 0,
#   '8178998': 0,
#   '2923497': 2,
#   '1396706': 0,
#   '3538162': 0,
#   '1772930': 0,
#   '2744909': 0},
#  '833860': {'6230229': 3,
#   '6230227': 3,
#   '6230226': 3,
#   '3437288': 3,
#   '1900578': 0,
#   '1900582': 0,
#   '6230220': 3,
#   '6230222': 3,
#   '1900579': 0,
#   '1900581': 0},
#  '19335': {'129764': 0,
#   '8412684': 3,
#   '3497214': 0,
#   '691498': 0,
#   '5454283': 0,
#   '3175478': 0,
#   '4540809': 0,
#   '4349928': 0,
#   '7298833': 0,
#   '7267248': 0},
#  '148538': {'1950974': 2,
#   '1950976': 1,
#   '1950979': 0,
#   '985491': 0,
#   '615405': 0,
#   '4185812': 1,
#   '4607267': 0,
#   '8181574': 0,
#   '3918785': 2,
#   '5844625': 0},
#  '168216': {'3174840': 3,
#   '13499': 3,
#   '2265769': 3,
#   '2069992': 3,
#   '6282561': 3,
#   '6213322': 3,
#   '3830857': 3,
#   '1381477': 3,
#   '3198689': 3,
#   '3908773': 3},
#  '962179': {'8689054': 0,
#   '5773189': 0,
#   '5427070': 0,
#   '5427063': 0,
#   '4309122': 0,
#   '2929469': 0,
#   '5427064': 0,
#   '2929465': 0,
#   '1006860': 0,
#   '4606389': 0},
#  '855410': {'8651775': 2,
#   '8651772': 1,
#   '8651771': 2,
#   '8651776': 0,
#   '8651770': 2},
#  '1121709': {'7796652': 0,
#   '1596222': 0,
#   '2255286': 0,
#   '5845418': 0,
#   '45202': 0,
#   '653094': 0,
#   '1860087': 0,
#   '1137958': 0,
#   '1596229': 0,
#   '1389460': 0},
#  '1037798': {'3641634': 3,
#   '8760873': 0,
#   '8760864': 0,
#   '6279828': 0,
#   '4978171': 0,
#   '6412269': 0,
#   '4916597': 0,
#   '1208969': 0,
#   '1308037': 0,
#   '8760866': 0},
#  '1112341': {'6740558': 0,
#   '2096429': 0,
#   '5497171': 0,
#   '2735215': 1,
#   '8139256': 3,
#   '1373648': 1,
#   '4538538': 0,
#   '550571': 0,
#   '2780681': 0,
#   '1998332': 3}}

# %%
precisions=[]
recalls=[]
common_queries = set(qrels_data.keys()) & set(scores_data.keys())
def intersection_and_length(dict, key, other_list):
    dict_list = dict.get(key, [])
    intersection = set(dict_list) & set(other_list)
    return len(intersection)
for qid in common_queries:
    doc_ids=scores_data[qid]
    len_of_intersection=intersection_and_length(qrels_data,qid,doc_ids)
    precisions.append([qid,(len_of_intersection/len(doc_ids))])
    base_recall=len(qrels_data[qid])
    display(base_recall)
    recalls.append([qid,(len_of_intersection/base_recall)])
# Out:
# 133
# 211
# 28
# 289
# 83
# 77
# 112
# 69
# 94
# 139
# 23
# 12
# 96
# 64
# 31
# 229
# 13
# 285
# 92
# 142
# 60
# 154
# 35
# 276
# 25
# 46
# 75
# 55
# 28
# 4
# 119
# 52
# 56
# 53
# 75
# 24
# 341
# 24
# 101
# 141
# 20
# 35
# 81

# %%
values=[value for _,value in precisions]
mean=sum(values)/len(values)
mean
# Out:
# 0.5162790697674419

# %% [markdown]
# ndcg

# %%
# Out:
# [['156493', 0.06015037593984962],
#  ['264014', 0.03317535545023697],
#  ['130510', 0.35714285714285715],
#  ['168216', 0.03460207612456748],
#  ['87181', 0.12048192771084337],
#  ['1113437', 0.025974025974025976],
#  ['47923', 0.08035714285714286],
#  ['573724', 0.10144927536231885],
#  ['443396', 0.0],
#  ['1124210', 0.07194244604316546],
#  ['146187', 0.17391304347826086],
#  ['1121709', 0.0],
#  ['489204', 0.03125],
#  ['131843', 0.125],
#  ['1103812', 0.06451612903225806],
#  ['183378', 0.034934497816593885],
#  ['1037798', 0.07692307692307693],
#  ['1133167', 0.03508771929824561],
#  ['915593', 0.010869565217391304],
#  ['1112341', 0.028169014084507043],
#  ['1106007', 0.016666666666666666],
#  ['451602', 0.025974025974025976],
#  ['1110199', 0.0],
#  ['1063750', 0.0],
#  ['962179', 0.0],
#  ['1121402', 0.21739130434782608],
#  ['833860', 0.08],
#  ['490595', 0.07272727272727272],
#  ['1129237', 0.17857142857142858],
#  ['855410', 1.0],
#  ['1117099', 0.03361344537815126],
#  ['1114646', 0.15384615384615385],
#  ['359349', 0.17857142857142858],
#  ['182539', 0.18867924528301888],
#  ['527433', 0.02666666666666667],
#  ['207786', 0.08333333333333333],
#  ['1114819', 0.020527859237536656],
#  ['1115776', 0.16666666666666666],
#  ['148538', 0.039603960396039604],
#  ['104861', 0.05673758865248227],
#  ['19335', 0.05],
#  ['405717', 0.11428571428571428],
#  ['87452', 0.07407407407407407]]
